# %% [markdown]
# ### Esse projeto consiste em fazer uma análise de dados relacionadas a exoplanetas. Vamos explorar como se deu a descoberta ao longo dos anos, o tipo de deteccção e algumas outras análises físicas. Em muitos gráficos vamos utilizar escala logarítmica em pelo menos um dos eixos.
#
# ####A base de dados utilizada foi retirada do archive oficial da Nasa: https://exoplanetarchive.ipac.caltech.edu/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importando as bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carregando o dataset
df = pd.read_csv("/content/drive/MyDrive/Machine Learning Senac/PS_2023.01.05_05.21.00.csv", sep =',')

# %%
#Verificando a quantidade de linhas e colunas da tabela
df.shape
# Out:
# (33855, 28)

# %%
#Verificando os tipos dos dados
df.dtypes
# Out:
# pl_name             object
# sy_snum              int64
# sy_pnum              int64
# discoverymethod     object
# disc_year            int64
# disc_facility       object
# disc_telescope      object
# disc_instrument     object
# soltype             object
# pl_orbper          float64
# pl_orbsmax         float64
# pl_massj           float64
# pl_bmassj          float64
# pl_orbeccen        float64
# pl_insol           float64
# pl_eqt             float64
# pl_trandur         float64
# st_spectype         object
# st_teff            float64
# st_rad             float64
# st_mass            float64
# st_met             float64
# st_metratio         object
# st_age             float64
# ra                 float64
# dec                float64
# sy_dist            float64
# sy_gaiamag;         object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33855 entries, 0 to 33854
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_name          33855 non-null  object
#  1   sy_snum          33855 non-null  int64
#  2   sy_pnum          33855 non-null  int64
#  3   discoverymethod  33855 non-null  object
#  4   disc_year        33855 non-null  int64
#  5   disc_facility    33855 non-null  object
#  6   disc_telescope   33855 non-null  object
#  7   disc_instrument  33855 non-null  object
#  8   soltype          33855 non-null  object
#  9   pl_orbper        30967 non-null  float64
#  10  pl_orbsmax       18537 non-null  float64
#  11  pl_massj         3074 non-null   float64
#  12  pl_bmassj        5062 non-null   float64
#  13  pl_orbeccen      16928 non-null  float64
#  14  pl_insol         14349 non-null  float64
#  15  pl_eqt           15406 non-null  float64
#  16  pl_trandur       20684 non-null  float64
#  17  st_spectype      1978 non-null   object
#  18  st_teff          31432 non-null  float64
#  19  st_rad           31552 non-null  float64
#  20  st_mass          28573 non-null  float64
#  21  st_met           21338 non-null  float64
#  22  st_metratio      21149 non-null  object
#  23  st_age           6796 non-null   float64
#  24  ra               33855 non-null  float64
#  25  dec              33855 non-null  float64
#  26  sy_dist          33055 non-null  float64
#  27  sy_gaiamag;      33855 non-null  object
# dtypes: float64(16), int64(3), object(9)
# memory usage: 7.2+ MB

# %%
#Significado de cada coluna:

# COLUMN pl_name:        Planet Name
# COLUMN sy_snum:        Number of Stars
# COLUMN sy_pnum:        Number of Planets
# COLUMN discoverymethod: Discovery Method
# COLUMN disc_year:      Discovery Year
# COLUMN disc_facility:  Discovery Facility
# COLUMN disc_telescope: Discovery Telescope
# COLUMN disc_instrument: Discovery Instrument
# COLUMN soltype:        Solution Type
# COLUMN pl_orbper:      Orbital Period [days]
# COLUMN pl_orbsmax:     Orbit Semi-Major Axis [au])
# COLUMN pl_massj:       Planet Mass [Jupiter Mass]
# COLUMN pl_bmassj:      Planet Mass or Mass*sin(i) [Jupiter Mass]
# COLUMN pl_orbeccen:    Eccentricity
# COLUMN pl_insol:       Insolation Flux [Earth Flux]
# COLUMN pl_eqt:         Equilibrium Temperature [K]
# COLUMN pl_trandur:     Transit Duration [hours]
# COLUMN st_spectype:    Spectral Type
# COLUMN st_teff:        Stellar Effective Temperature [K]
# COLUMN st_rad:         Stellar Radius [Solar Radius]
# COLUMN st_mass:        Stellar Mass [Solar mass]
# COLUMN st_met:         Stellar Metallicity [dex]
# COLUMN st_metratio:    Stellar Metallicity Ratio
# COLUMN st_age:         Stellar Age [Gyr]
# COLUMN ra:             RA [deg]
# COLUMN dec:            Dec [deg]
# COLUMN sy_dist:        Distance [pc]
# COLUMN sy_gaiamag:     Gaia Magnitude

# %%
#Lendo as cinco primeiras linhas da tabela
df.head()
# Out:
#     pl_name  sy_snum  sy_pnum  discoverymethod  disc_year  \
# 0  11 Com b        2        1  Radial Velocity       2007
# 1  11 Com b        2        1  Radial Velocity       2007
# 2  11 UMi b        1        1  Radial Velocity       2009
# 3  11 UMi b        1        1  Radial Velocity       2009
# 4  11 UMi b        1        1  Radial Velocity       2009
#
#                             disc_facility                 disc_telescope  \
# 0                        Xinglong Station               2.16 m Telescope
# 1                        Xinglong Station               2.16 m Telescope
# 2  Thueringer Landessternwarte Tautenburg  2.0 m Alfred Jensch Telescope
# 3  Thueringer Landessternwarte Tautenburg  2.0 m Alfred Jensch Telescope
# 4  Thueringer Landessternwarte Tautenburg  2.0 m Alfred Jensch Telescope
#
#               disc_instrument              soltype  pl_orbper  ...  st_teff  \
# 0  Coude Echelle Spectrograph  Published Confirmed  326.03000  ...   4742.0
# 1  Coude Echelle Spectrograph  Published Confirmed        NaN  ...      NaN
# 2  Coude Echelle Spectrograph  Published Confirmed  516.22000  ...   4340.0
# 3  Coude Echelle Spectrograph  Published Confirmed        NaN  ...      NaN
# 4  Coude Echelle Spectrograph  Published Confirmed  516.21997  ...   4213.0
#
#    st_rad  st_mass  st_met  st_metratio  st_age          ra        dec  \
# 0   19.00     2.70   -0.35       [Fe/H]     NaN  185.178779  17.793252
# 1     NaN     2.60     NaN          NaN     NaN  185.178779  17.793252
# 2   24.08     1.80    0.04       [Fe/H]    1.56  229.274595  71.823943
# 3     NaN     1.70     NaN          NaN     NaN  229.274595  71.823943
# 4   29.79     2.78   -0.02       [Fe/H]     NaN  229.274595  71.823943
#
#     sy_dist  sy_gaiamag;
# 0   93.1846   4.4403800;
# 1   93.1846   4.4403800;
# 2  125.3210   4.5621600;
# 3  125.3210   4.5621600;
# 4  125.3210   4.5621600;
#
# [5 rows x 28 columns]

# %%
#Removendo as linhas com exoplanetas de mesmo nome e mantendo apenas a primeira não repetida
df = df.drop_duplicates(subset='pl_name', keep='first')

# %%
#Agora temos exatamente a quantidade de exoplanetas confirmados na data de downlowad do dataset
df.shape
# Out:
# (5235, 28)

# %%
df.isnull().sum()
# Out:
# pl_name               0
# sy_snum               0
# sy_pnum               0
# discoverymethod       0
# disc_year             0
# disc_facility         0
# disc_telescope        0
# disc_instrument       0
# soltype               0
# pl_orbper           433
# pl_orbsmax         2019
# pl_massj           4440
# pl_bmassj          3520
# pl_orbeccen        2401
# pl_insol           3421
# pl_eqt             3109
# pl_trandur         2584
# st_spectype        4372
# st_teff             667
# st_rad              749
# st_mass             813
# st_met             1974
# st_metratio        2017
# st_age             3935
# ra                    0
# dec                   0
# sy_dist             122
# sy_gaiamag;           0
# dtype: int64

# %%
df['discoverymethod'].value_counts()
# Out:
# Transit                          3941
# Radial Velocity                  1022
# Microlensing                      148
# Imaging                            62
# Transit Timing Variations          23
# Eclipse Timing Variations          18
# Orbital Brightness Modulation       9
# Pulsar Timing                       7
# Astrometry                          2
# Pulsation Timing Variations         2
# Disk Kinematics                     1
# Name: discoverymethod, dtype: int64

# %%
#Criando uma coluna de Transito e colocando como 0 e 1
df['Transito'] = df['discoverymethod'] == 'Transit'
df['Transito'] = df['Transito'].map({True:1, False:0})

# %%
#Criando uma coluna de Velocidade Radial e colocando como 0 e 1
df['Velocidade Radial'] = df['discoverymethod'] == 'Radial Velocity'
df['Velocidade Radial'] = df['Velocidade Radial'].map({True:1, False:0})

# %%
#Criando uma coluna de Microlentes e colocando como 0 e 1
df['Microlentes'] = df['discoverymethod'] == 'Microlensing'
df['Microlentes'] = df['Microlentes'].map({True:1, False:0})

# %%
#Criando uma coluna de Imaging e colocando como 0 e 1
df['Imageamento'] = df['discoverymethod'] == 'Imaging'
df['Imageamento'] = df['Imageamento'].map({True:1, False:0})

# %%
#Agora temos exatamente a quantidade de exoplanetas e as duas novas colunas
df.shape
# Out:
# (5235, 32)

# %%
df.head()
# Out:
#        pl_name  sy_snum  sy_pnum  discoverymethod  disc_year  \
# 0     11 Com b        2        1  Radial Velocity       2007
# 2     11 UMi b        1        1  Radial Velocity       2009
# 5     14 And b        1        1  Radial Velocity       2008
# 7     14 Her b        1        2  Radial Velocity       2002
# 15  16 Cyg B b        3        1  Radial Velocity       1996
#
#                              disc_facility                 disc_telescope  \
# 0                         Xinglong Station               2.16 m Telescope
# 2   Thueringer Landessternwarte Tautenburg  2.0 m Alfred Jensch Telescope
# 5        Okayama Astrophysical Observatory               1.88 m Telescope
# 7                   W. M. Keck Observatory          10 m Keck I Telescope
# 15                  Multiple Observatories            Multiple Telescopes
#
#                disc_instrument              soltype  pl_orbper  ...  \
# 0   Coude Echelle Spectrograph  Published Confirmed     326.03  ...
# 2   Coude Echelle Spectrograph  Published Confirmed     516.22  ...
# 5   HIDES Echelle Spectrograph  Published Confirmed     185.84  ...
# 7           HIRES Spectrometer  Published Confirmed    1796.40  ...
# 15        Multiple Instruments  Published Confirmed     798.50  ...
#
#     st_metratio  st_age          ra        dec   sy_dist  sy_gaiamag;  \
# 0        [Fe/H]     NaN  185.178779  17.793252   93.1846   4.4403800;
# 2        [Fe/H]    1.56  229.274595  71.823943  125.3210   4.5621600;
# 5        [Fe/H]     NaN  352.824150  39.235837   75.4392   4.9178100;
# 7        [Fe/H]    3.90  242.602101  43.816362   17.9323   6.3830000;
# 15       [Fe/H]     NaN  295.465642  50.516824   21.1397   6.0642800;
#
#     Transito Velocidade Radial  Microlentes  Imageamento
# 0          0                 1            0            0
# 2          0                 1            0            0
# 5          0                 1            0            0
# 7          0                 1            0            0
# 15         0                 1            0            0
#
# [5 rows x 32 columns]

# %%
##Verificando novamente os tipos dos dados
df.dtypes
# Out:
# pl_name               object
# sy_snum                int64
# sy_pnum                int64
# discoverymethod       object
# disc_year              int64
# disc_facility         object
# disc_telescope        object
# disc_instrument       object
# soltype               object
# pl_orbper            float64
# pl_orbsmax           float64
# pl_massj             float64
# pl_bmassj            float64
# pl_orbeccen          float64
# pl_insol             float64
# pl_eqt               float64
# pl_trandur           float64
# st_spectype           object
# st_teff              float64
# st_rad               float64
# st_mass              float64
# st_met               float64
# st_metratio           object
# st_age               float64
# ra                   float64
# dec                  float64
# sy_dist              float64
# sy_gaiamag;           object
# Transito               int64
# Velocidade Radial      int64
# Microlentes            int64
# Imageamento            int64
# dtype: object

# %%
#Contabilizando os exoplanetas
df['pl_name'].value_counts()
# Out:
# 11 Com b        1
# Kepler-306 d    1
# Kepler-313 b    1
# Kepler-312 c    1
# Kepler-312 b    1
#                ..
# K2-97 b         1
# K2-95 b         1
# K2-91 b         1
# K2-90 c         1
# xi Aql b        1
# Name: pl_name, Length: 5235, dtype: int64

# %%
#Verificando o status final dos exoplanetas
df['soltype'].value_counts()
# Out:
# Published Confirmed                               3186
# Kepler Project Candidate (q1_q17_dr25_koi)         293
# Kepler Project Candidate (q1_q12_koi)              286
# Kepler Project Candidate (q1_q17_dr24_koi)         281
# Kepler Project Candidate (q1_q16_koi)              279
# Kepler Project Candidate (q1_q17_dr25_sup_koi)     275
# Kepler Project Candidate (q1_q8_koi)               234
# Published Candidate                                202
# TESS Project Candidate                             199
# Name: soltype, dtype: int64

# %%
#Verificando o Método de deteccão dos Exoplanetas
df['discoverymethod'].value_counts()
# Out:
# Transit                          3941
# Radial Velocity                  1022
# Microlensing                      148
# Imaging                            62
# Transit Timing Variations          23
# Eclipse Timing Variations          18
# Orbital Brightness Modulation       9
# Pulsar Timing                       7
# Astrometry                          2
# Pulsation Timing Variations         2
# Disk Kinematics                     1
# Name: discoverymethod, dtype: int64

# %%
#Verificando a quantidade de Exoplanetas descobertos a cada ano
df['disc_year'].value_counts()
# Out:
# 2016    1518
# 2014     875
# 2021     525
# 2022     331
# 2018     326
# 2020     233
# 2019     203
# 2015     157
# 2017     153
# 2012     139
# 2011     138
# 2013     126
# 2010      97
# 2009      94
# 2008      65
# 2007      52
# 2005      36
# 2006      31
# 2002      29
# 2004      27
# 2003      22
# 2000      16
# 1999      13
# 2001      12
# 1996       6
# 1998       6
# 1992       2
# 1995       1
# 1994       1
# 1997       1
# Name: disc_year, dtype: int64

# %% [markdown]
# ### **Fizemos um breve e necessário tratamento nos dados, agora podemos começar a plotar gráficos das situações de interesse.**
#
# ####**Vamos começar com o gráfico de descoberta de exoplanetas ao longo dos anos**
#
# ####**Para uma melhor visualização vamos deixar o eixo y em escala logarítimica**

# %%
#Gráfico da quantidade de exoplanetas descobertos por ano
plt.figure(figsize=(15, 10))
df['disc_year'].value_counts().plot.bar()
plt.yscale("log")
plt.xticks(rotation =55, fontsize=12)
plt.xlabel("Ano", fontsize=12)
plt.ylabel("Quantidade de Exoplanetas", fontsize=12)
plt.title("Quantidade de Exoplanetas Descobertos por ano", fontsize = 14)
plt.show()

# %% [markdown]
# ### **Há diversas formas de detecção de exoplanetas, onde as mais comuns são Trânsito Planetário e Velocidade Radial.**
#
# ### **De maneira simplificada a detecção por trânsito se dá ao analisar as curvas de luz da estrela e verificar uma diminuição periodica da curva de luz. Já o método de velocidade radial consiste na detecção da variação da velocidade radial da estrela, causando um Efeito Doppler, com isso as linhas espectrais sofrem blueshift e redshift.**
#
# ####Para mais informações: https://pt.wikipedia.org/wiki/M%C3%A9todos_de_detec%C3%A7%C3%A3o_de_exoplanetas

# %%
#Gráfico da quantidade de exoplanetas descobertos por cada método de detecção
plt.figure(figsize=(16, 10))
df['discoverymethod'].value_counts().plot.bar()
plt.yscale("log")
plt.xticks(rotation =55, fontsize=12)
plt.xlabel("Método de Detecção", fontsize=14)
plt.ylabel("Exoplanetas Descobertos", fontsize=14)
plt.title("Métodos de detecção de Exoplanetas", fontsize=14)
plt.show()

# %%
#Valores do Gráfico acima
df["discoverymethod"].value_counts()
# Out:
# Transit                          3941
# Radial Velocity                  1022
# Microlensing                      148
# Imaging                            62
# Transit Timing Variations          23
# Eclipse Timing Variations          18
# Orbital Brightness Modulation       9
# Pulsar Timing                       7
# Astrometry                          2
# Pulsation Timing Variations         2
# Disk Kinematics                     1
# Name: discoverymethod, dtype: int64

# %% [markdown]
# ### **Os exoplanetas foram descobertos através de diferentes instrumentos.**
#
# ### **A seguir vemos cada telescopio que contribuiu e a quantidade de exoplanetas descobertos por cada um.**

# %%
#Verificando a quantidade de planetas descobertas por cada telescópio/missão espacial.
df['disc_facility'].value_counts()
# Out:
# Kepler                                          2710
# K2                                               543
# Transiting Exoplanet Survey Satellite (TESS)     285
# Multiple Observatories                           273
# La Silla Observatory                             270
#                                                 ...
# Leoncito Astronomical Complex                      1
# NASA Infrared Telescope Facility (IRTF)            1
# KOINet                                             1
# SPECULOOS Southern Observatory                     1
# Winer Observatory                                  1
# Name: disc_facility, Length: 67, dtype: int64

# %%
#Gráfico da quantidade de exoplanetas descobertos por cada telescópio
plt.figure(figsize=(27,10))
#df['disc_facility'].value_counts().plot.bar(fontsize=14)
df['disc_facility'].value_counts().plot(kind ='bar', fontsize=12)
plt.yscale("log")
#plt.xticks(rotation =90, fontsize=12)
plt.ylabel("Telescópios", fontsize=14)
plt.xlabel("Exoplanetas Descobertos", fontsize=14)
plt.title("Descoberta de exoplanetas por telescópio", fontsize=14)
plt.show()

# %% [markdown]
# ### **Uma das maneiras de identificar um objeto celeste é através de suas coordenadas, elas são chamadas de Ascensão Reta e Declinação.**
#
# ### **A seguir vemos um "mapa" da distribuição dos exoplanetas utilizando essas coordenadas.**
#
# ### Para mais informações: https://pt.wikipedia.org/wiki/Sistema_equatorial_de_coordenadas

# %%
#Distribuição dos Planetas de acordo com Ascensão Reta e Declinação
ra = df.ra
dec = df.dec
fig = plt.figure(figsize=(12, 12))
plt.scatter(ra,dec, s=7, label="RA,DEC")
plt.xlabel("Ascensão Reta" ,fontsize =12)
plt.ylabel("Declinação", fontsize =12)
plt.title("Mapa dos exoplanetas", fontsize =12)
plt.legend(fontsize =10)
plt.show()

# %% [markdown]
# ### **Há diversos parâmetros quando estamos fazendo uma análise de dados que é interessante fazer gráficos para exoplorar padrões e correlações.**
#
# ### **A seguir vamos começar por um gráfico de Período Orbital x Massa do Planeta.**

# %%
#Distribuição de período orbital por massa
pl_porb = df.pl_orbper
pl_mass = df.pl_massj
fig = plt.figure(figsize=(12, 12))
plt.scatter(pl_porb,pl_mass, s=25, label="Exoplanetas", color="darkblue", alpha =0.6)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Período Orbital do Planeta " ,fontsize =12)
plt.ylabel("Massa do Planeta (M_j)", fontsize =12)
plt.title("Período Orbital x Massa do Planeta", fontsize =12)
plt.legend(fontsize =10)
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Ao analisar o gráfico acima vemos uma concentração maior de Exoplanetas com massa próximo a uma massa de Júpiter e período orbital menor que 100 dias.**
#
# ### **A explicação disso está na limitação tecnológica dos métodos de detecção. A maior fonte de deteccção, como já foi visto, foi através de trânsito planetário. Nessa forma é muito mais fácil encontrar planetas com períodos de curta duração e grandes massas, esses são conhecidos como Júpiters Quentes.**
#
# ### **A seguir vamos mostrar um histograma da distribuição da massa dos exoplanetas em relação a massa de júpiter. Vamos ver que a grande maioria dos planetas descobertos tem até 5 massas de Júpiter**

# %%
#Histograma das massas dos planetas em relação a massas de Júpiter
planet_mass = df['pl_massj']
plt.figure(figsize=(8, 6))
plt.hist(planet_mass, label ="Exoplanetas", color = "purple")
plt.xlabel("Massa do planeta (M_j) " ,fontsize =12)
plt.ylabel("Quantidade de Exoplanetas", fontsize =12)
plt.yscale("log")
plt.title("Distribuição das massas dos planetas em M_j", fontsize =12)
plt.xticks(np.arange(0, 45,5),fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# ### **Agora vamos verificar a duração dos trânsitos planetários. Quanto menor o tempo do trânsito, mais fácil do exoplaneta ser detectado, pois maior será a periodicidade com que ele passa na frente da estrela.**

# %%
#Histograma da duração dos Trânsitos Planetários
planet_transdur = df['pl_trandur']
plt.figure(figsize=(8, 6))
plt.hist(planet_transdur, label ="Exoplanetas", color = "lightcoral")
plt.xlabel("Duração do Trânsito (horas) " ,fontsize =12)
plt.ylabel("Quantidade de Exoplanetas", fontsize =12)
plt.yscale("log")
plt.title("Duração dos Trânsitos Planetários", fontsize =12)
#plt.xticks(np.arange(0, 45,5),fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# ### **Um dos parâmetros conhecidos quando se estuda planetas e estrelas é a ecentricidade.**
#
# ### **Quanto mais próximo de zero for a ecentricidade, mais se aproxima de um círculo perfeito.**

# %%
#Gráfico Ecentricidade dos Planetas
pl_ecc = df.pl_orbeccen
plt.figure(figsize=(10, 8))
plt.hist(pl_ecc,  label ='Ecentricidade', color = 'lightblue', bins=np.arange(0,1.1,0.1))
plt.title('Distribuição da ecentricidade')
plt.xlabel('Ecentricidade')
plt.yscale("log")
plt.ylabel("Quantidade de Exoplanetas")
plt.xticks(np.arange(0, 1.1, 0.1),fontsize=12)
plt.legend()
plt.show()
plt.show()

# %% [markdown]
# ### **Vamos verificar a distribuição das temperaturas dos exoplanetas.**

# %%
#Histograma distribuição de temperatura
pl_temp = df.pl_eqt
plt.figure(figsize=(10, 8))
plt.hist(pl_temp,  label ='Exoplanetas', color = 'orange')
plt.title('Distribuição da Temperatura de Equilíbrio', fontsize=12)
plt.xlabel('Temperatura (K)', fontsize=12)
plt.ylabel("Quantidade de Exoplanetas", fontsize=12)
plt.legend()
plt.show()
plt.show()

# %% [markdown]
# ### **Agora vamos verificar a relação entre Temperatura do exoplaneta e período orbital.**
#
# ### **Pela lógica, devemos esperar que quanto maior o período orbital, menor será a temperatura do exoplaneta. Lembre-se do nosso sistema solar, por exemplo.**
#
# ### **Obtemos exatamente o valor esperado, conforme o gráfico abaixo**

# %%
#Distribuição de período orbital por temperatura
pl_porb = df.pl_orbper
pl_temp = df.pl_eqt

fig = plt.figure(figsize=(12, 12))
plt.scatter(pl_porb, pl_temp, s=20, label="Exoplanetas")

plt.xscale("log")
plt.yscale("log")
plt.xlabel("Período Orbital" ,fontsize =12)
plt.ylabel("Temperatura do exoplaneta", fontsize =12)
plt.title("Período Orbital x Temperatura", fontsize =12)
plt.legend(fontsize =12)
plt.show()

# %% [markdown]
# ## **Agora vamos verificar também os Parâmetros Estelares.**

# %% [markdown]
# ### **Verificando a massa das estrelas com exoplanetas em relação as massas solares.**

# %%
df['st_mass'].value_counts().sort_values()
# Out:
# 3.09      1
# 2.13      1
# 2.20      1
# 9.10      1
# 2.45      1
#        ...
# 1.03     91
# 1.01     95
# 1.02     96
# 0.97     98
# 1.00    105
# Name: st_mass, Length: 235, dtype: int64

# %%
#Histograma da Massa das estrelas descobertas, a unidade está em massas solares
star_mass = df.st_mass
plt.figure(figsize=(10, 8))
plt.hist(star_mass, label ='Estrelas', color = 'cadetblue', rwidth=0.9, bins=11)
plt.title("Massa solares das Estrelas")
plt.xlabel("Massas Solares",fontsize=12)
plt.ylabel("Quantidade",fontsize=12)
plt.xticks(np.arange(0, 12,1),fontsize=12)
plt.yscale("log")
plt.legend()
plt.show()

# %% [markdown]
# ### **Vamos fazer um histograma com a idade das estrelas em Giga ($10^9$) anos.**

# %%
star_age = df.st_age
plt.figure(figsize=(10, 8))
plt.hist(star_age, label ='Estrelas', color = 'blue', rwidth=0.9,alpha =0.5)
plt.title("Idade das Estrelas em Giga ($10^9$) anos",fontsize=12)
plt.xlabel("Idade",fontsize=12)
plt.ylabel("Quantidade de Estrelas",fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# ### **Vamos verificar a relação entre Massa Estelar e Temperatura Estelar.**

# %%
#Distribuição de Massa vs Temp
st_massa = df.st_mass
st_temp = df.st_teff

fig = plt.figure(figsize=(12, 12))
plt.scatter(st_massa,st_temp, s=20, label="Exoplanetas", color ='darkblue', alpha =0.3)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Massa Estelar em M_s", fontsize =12)
plt.ylabel("Temperatura Efetiva (K)" ,fontsize =12)
#plt.yticks(np.arange(0, 10000,2000),fontsize=12)
plt.title("Gráfico de dispersão de Massa Estelar x Temperatura Efetiva", fontsize =12)
plt.legend(fontsize =10)
plt.show()

# %% [markdown]
# ### **Vamos verificar a relação entre a massa da estrela e sua idade**

# %%
#Distribuição de Massa vs Idade da estrela
st_massa = df.st_mass
st_idade = df.st_age

fig = plt.figure(figsize=(10, 8))
plt.scatter(st_idade, st_massa,s=20, label="Estrelas", color ='lightseagreen')
plt.xscale("log")
plt.yscale("log")

plt.xlabel("Massa Estelar em M_s", fontsize =12)
plt.ylabel("Idade estelar" ,fontsize =12)
plt.title("Massa Estelar x Idade estelar", fontsize =12)
plt.legend(fontsize =10)
plt.show()

# %% [markdown]
# ### **Vamos também analisar a metalicidade e idade**

# %%
#Distribuição de Metalicidade vs Idade da estrela
st_age = df.st_age
st_met = df.st_met

fig = plt.figure(figsize=(10, 8))
plt.scatter(st_age, st_met, s=20, label="Estrelas", color ='mediumpurple')


plt.ylabel("Metalicidade", fontsize =12)
plt.xlabel("Idade estelar" ,fontsize =12)
plt.title("Metalicidade x Idade Estelar", fontsize =12)
plt.legend(fontsize =10)
plt.show()

# %%
#Histograma de distribuição da Metalicidade
st_met = df.st_met
plt.figure(figsize=(10, 8))
plt.hist(st_met, label ='Estrelas', color = 'royalblue', rwidth=0.9)
plt.title("Distribuição de Metalicidade",fontsize=12)
plt.xlabel("Metalicidade",fontsize=12)
plt.ylabel("Quantidade de Estrelas",fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# ### **Vamos criar um sub dataframe com algumas variáveis de interesse e chama-lo de 'df1'.**
#
# ### **Mas antes, para facilitar, vamos listar todas as colunas.**

# %%
df.columns.to_list()
# Out:
# ['pl_name',
#  'sy_snum',
#  'sy_pnum',
#  'discoverymethod',
#  'disc_year',
#  'disc_facility',
#  'disc_telescope',
#  'disc_instrument',
#  'soltype',
#  'pl_orbper',
#  'pl_orbsmax',
#  'pl_massj',
#  'pl_bmassj',
#  'pl_orbeccen',
#  'pl_insol',
#  'pl_eqt',
#  'pl_trandur',
#  'st_spectype',
#  'st_teff',
#  'st_rad',
#  'st_mass',
#  'st_met',
#  'st_metratio',
#  'st_age',
#  'ra',
#  'dec',
#  'sy_dist',
#  'sy_gaiamag;',
#  'Transito',
#  'Velocidade Radial',
#  'Microlentes',
#  'Imageamento']

# %%
df1 = df[['pl_orbper','pl_orbsmax',	'pl_massj','pl_orbeccen','pl_insol','pl_eqt','pl_trandur','st_spectype','st_teff','st_rad','st_mass','st_met','st_metratio','st_age']]

# %% [markdown]
# ### **Com os dados podemos criar um mapa de calor para verificar as correlações.**

# %%
#Criando a matriz de correlações
#df1 = {df['sy_snum'],df['sy_pnum'],df['disc_year']}
correlacao = df1.corr(numeric_only = True)
ax = sns.heatmap(correlacao, annot = True)
sns.color_palette("pastel")
ax.figure.set_size_inches(15,10)

# %%
#Visualizando a matriz em forma de tabela
df1.corr()
# Out:
# <ipython-input-46-1b564e395021>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#              pl_orbper  pl_orbsmax  pl_massj  pl_orbeccen  pl_insol    pl_eqt  \
# pl_orbper     1.000000    0.997282  0.025685     0.061348 -0.054913 -0.020796
# pl_orbsmax    0.997282    1.000000  0.158253     0.141620 -0.134290  0.052736
# pl_massj      0.025685    0.158253  1.000000     0.415107  0.578159  0.332437
# pl_orbeccen   0.061348    0.141620  0.415107     1.000000 -0.022232 -0.019597
# pl_insol     -0.054913   -0.134290  0.578159    -0.022232  1.000000  0.635502
# pl_eqt       -0.020796    0.052736  0.332437    -0.019597  0.635502  1.000000
# pl_trandur    0.639877    0.794697  0.367320     0.040934 -0.098319 -0.283002
# st_teff      -0.018964   -0.034687  0.042952    -0.014183  0.242421  0.425042
# st_rad       -0.004996   -0.006408  0.181448     0.156371  0.452317  0.433314
# st_mass      -0.023170   -0.018846  0.163101     0.121385  0.250152  0.480705
# st_met        0.001876    0.006774  0.055483     0.171055  0.086067  0.176444
# st_age       -0.036534   -0.109353 -0.389705    -0.045774 -0.200445 -0.176299
#
#              pl_trandur   st_teff    st_rad   st_mass    st_met    st_age
# pl_orbper      0.639877 -0.018964 -0.004996 -0.023170  0.001876 -0.036534
# pl_orbsmax     0.794697 -0.034687 -0.006408 -0.018846  0.006774 -0.109353
# pl_massj       0.367320  0.042952  0.181448  0.163101  0.055483 -0.389705
# pl_orbeccen    0.040934 -0.014183  0.156371  0.121385  0.171055 -0.045774
# pl_insol      -0.098319  0.242421  0.452317  0.250152  0.086067 -0.200445
# pl_eqt        -0.283002  0.425042  0.433314  0.480705  0.176444 -0.176299
# pl_trandur     1.000000  0.305553  0.301627  0.315268 -0.004402 -0.093177
# st_teff        0.305553  1.000000 -0.052659  0.224991  0.070786 -0.148900
# st_rad         0.301627 -0.052659  1.000000  0.548083 -0.117697 -0.051670
# st_mass        0.315268  0.224991  0.548083  1.000000  0.114620 -0.253994
# st_met        -0.004402  0.070786 -0.117697  0.114620  1.000000 -0.049460
# st_age        -0.093177 -0.148900 -0.051670 -0.253994 -0.049460  1.000000

# %% [markdown]
# ### **Também podemos criar histogramas de todas essas variáveis.**

# %%
df1.hist(figsize=(14,14))
plt.show()

# %% [markdown]
# ## Quantidade de exoplanetas descobertos por cada método ao longo dos anos

# %%
plt.figure(figsize=(10, 8))
df.groupby(df["disc_year"])["Transito"].sum().plot()
df.groupby(df["disc_year"])["Velocidade Radial"].sum().plot()
df.groupby(df["disc_year"])["Microlentes"].sum().plot()
df.groupby(df["disc_year"])["Imageamento"].sum().plot()
plt.yscale("log")
plt.title("Quantidade de exoplanetas descobertos por cada método por ano",fontsize=12)
plt.xlabel("Ano",fontsize=12)
plt.ylabel("Quantidade de Exoplanetas",fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# ## Comparação apenas entre Trânsito e Velocidade Radial. Vemos o aumento expressivo no método de Trânsito principalmente a partir de 2010 devido a missão Kepler

# %%
# Comparação apenas entre Trânsito e Velocidade Radial
plt.figure(figsize=(10, 8))
df.groupby(df["disc_year"])["Transito"].sum().plot()
df.groupby(df["disc_year"])["Velocidade Radial"].sum().plot()
plt.yscale("log")
plt.title("Quantidade de exoplanetas descobertos por cada método por ano",fontsize=12)
plt.xlabel("Ano",fontsize=12)
plt.ylabel("Quantidade de Exoplanetas",fontsize=12)
plt.legend()
plt.show()

# %%
df.groupby(df["disc_year"])["Velocidade Radial"].sum()
# Out:
# disc_year
# 1992      0
# 1994      0
# 1995      1
# 1996      6
# 1997      1
# 1998      6
# 1999     13
# 2000     16
# 2001     12
# 2002     28
# 2003     21
# 2004     18
# 2005     33
# 2006     21
# 2007     34
# 2008     37
# 2009     73
# 2010     41
# 2011     47
# 2012     34
# 2013     32
# 2014     50
# 2015     47
# 2016     49
# 2017     49
# 2018     49
# 2019     66
# 2020     45
# 2021     78
# 2022    115
# Name: Velocidade Radial, dtype: int64

# %%
# Quantidade total de exoplanetas descobertos por Trânsito
 (df['Transito']== 1).sum()
# Out:
#   File "<ipython-input-51-61578c297781>", line 2
#     (df['Transito']== 1).sum()
#     ^
# IndentationError: unexpected indent
